# %%
import pandas as pd

intial_samples = pd.read_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/smok_MG_20210218_beta.csv')
new_samples = pd.read_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/smok_MG_20211006_beta.csv')

# %%
new_column_names = []
for i in range(341,713):
  new_column_names.append('V'+str(i))

new_samples.columns = new_column_names

# %%
new_samples
# Out:
#             V341      V342      V343      V344      V345      V346      V347  \
# 0       0.329020  0.276514  0.261077  0.349474  0.218893  0.277733  0.297211
# 1       0.805241  0.833944  0.728742  0.809474  0.696195  0.709426  0.748535
# 2       0.620953  0.565122  0.669494  0.694689  0.593909  0.694658  0.752755
# 3       0.348812  0.275805  0.276869  0.295531  0.257462  0.224728  0.228167
# 4       0.539363  0.532072  0.470148  0.467524  0.630146  0.481330  0.599593
# ...          ...       ...       ...       ...       ...       ...       ...
# 185461  0.972267  0.331610  0.996486  0.960399  0.408185  0.659793  0.356206
# 185462  1.000000  1.000000  0.126244  0.501037  0.480462  0.026381  0.454363
# 185463  0.539184  0.610375  0.552159  0.113796  0.554293  0.042083  0.503147
# 185464  0.158597  0.446488  0.364211  0.326148  0.080186  0.177763  0.359078
# 185465  0.402599  0.852758  0.481549  0.877044  0.926673  0.647778  0.926065
#
#             V348      V349      V350  ...      V703      V704      V705  \
# 0       0.307130  0.191178  0.242173  ...  0.295363  0.269285  0.200506
# 1       0.735753  0.801774  0.855830  ...  0.776553  0.730589  0.702946
# 2       0.586651  0.664878  0.639520  ...  0.501355  0.548397  0.665720
# 3       0.222159  0.233768  0.256849  ...  0.278450  0.271953  0.252710
# 4       0.603932  0.660843  0.652968  ...  0.600876  0.569462  0.547136
# ...          ...       ...       ...  ...       ...       ...       ...
# 185461  0.350371  0.435047  0.739547  ...  0.406146  0.485601  1.000000
# 185462  0.530872  0.030251  1.000000  ...  0.470173  0.044474  0.075201
# 185463  0.622974  0.572942  0.064702  ...  0.120422  0.905024  0.945635
# 185464  0.435049  0.466625  0.761815  ...  0.072437  0.399460  0.370722
# 185465  0.912650  0.454945  0.792167  ...  0.942565  0.950327  0.437199
#
#             V706      V707      V708      V709      V710      V711      V712
# 0       0.287746  0.270197  0.281535  0.286554  0.407166  0.310062  0.391401
# 1       0.779648  0.735675  0.705492  0.790483  0.690458  0.724156  0.757640
# 2       0.669068  0.584368  0.661179  0.628714  0.759815  0.721282  0.655844
# 3       0.215268  0.287516  0.220892  0.226521  0.331133  0.276802  0.308346
# 4       0.508531  0.526622  0.457632  0.677037  0.453161  0.602333  0.559536
# ...          ...       ...       ...       ...       ...       ...       ...
# 185461  1.000000  0.434069  0.394809  1.000000  0.324161  0.565208  0.477492
# 185462  1.000000  0.450406  0.444934  1.000000  1.000000  0.947480  0.722071
# 185463  0.552624  0.555319  0.604723  0.125767  0.533930  0.970449  0.082995
# 185464  0.471672  0.365842  0.320819  0.417000  0.915184  0.420178  0.401040
# 185465  0.873139  0.948403  0.909482  0.908893  0.759576  0.750422  0.505396
#
# [185466 rows x 372 columns]

# %%
full_dna_data = intial_samples.join(new_samples)

# %%
full_dna_data
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 
# ...          ...       ...       ...       ...       ...       ...       ...
# 185461  0.972267  0.046713  0.331610  0.556525  0.408185  0.659793  0.213117
# 185462  1.000000  1.000000  1.000000  1.000000  0.480462  0.026381  0.443341
# 185463  0.539184  0.500367  0.610375  0.610816  0.554293  0.042083  0.927026
# 185464  0.158597  0.323595  0.446488  0.406586  0.080186  0.177763  0.164656
# 185465  0.402599  0.932810  0.852758  0.843049  0.926673  0.647778  0.819935
#
#               V8        V9       V10  ...      V703      V704      V705  \
# 0       0.497615  0.303142  0.283008  ...  0.295363  0.269285  0.200506
# 1       0.746814  0.597846  0.826694  ...  0.776553  0.730589  0.702946
# 2       0.759320  0.646269  0.484979  ...  0.501355  0.548397  0.665720
# 3       0.354580  0.282824  0.298875  ...  0.278450  0.271953  0.252710
# 4       0.611644  0.468918  0.616326  ...  0.600876  0.569462  0.547136
# ...          ...       ...       ...  ...       ...       ...       ...
# 185461  0.584555  0.618830  1.000000  ...  0.406146  0.485601  1.000000
# 185462  0.524958  0.654733  0.091362  ...  0.470173  0.044474  0.075201
# 185463  0.542625  0.130027  0.964641  ...  0.120422  0.905024  0.945635
# 185464  0.785506  0.412523  0.273186  ...  0.072437  0.399460  0.370722
# 185465  0.399649  0.833564  0.812037  ...  0.942565  0.950327  0.437199
#
#             V706      V707      V708      V709      V710      V711      V712
# 0       0.287746  0.270197  0.281535  0.286554  0.407166  0.310062  0.391401
# 1       0.779648  0.735675  0.705492  0.790483  0.690458  0.724156  0.757640
# 2       0.669068  0.584368  0.661179  0.628714  0.759815  0.721282  0.655844
# 3       0.215268  0.287516  0.220892  0.226521  0.331133  0.276802  0.308346
# 4       0.508531  0.526622  0.457632  0.677037  0.453161  0.602333  0.559536
# ...          ...       ...       ...       ...       ...       ...       ...
# 185461  1.000000  0.434069  0.394809  1.000000  0.324161  0.565208  0.477492
# 185462  1.000000  0.450406  0.444934  1.000000  1.000000  0.947480  0.722071
# 185463  0.552624  0.555319  0.604723  0.125767  0.533930  0.970449  0.082995
# 185464  0.471672  0.365842  0.320819  0.417000  0.915184  0.420178  0.401040
# 185465  0.873139  0.948403  0.909482  0.908893  0.759576  0.750422  0.505396
#
# [185466 rows x 712 columns]

# %%
df_dna = df_dna.T

# %%
df_dna.shape
# Out:
# (712, 185466)

# %%
df_dna = df_dna.to_numpy()

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

df_dna_scaled = StandardScaler().fit_transform(df_dna)

# %%
df_dna_scaled
# Out:
# array([[ 0.15198498,  0.8536411 , -0.35346204, ...,  0.17362116,
#         -0.89931176, -1.58306336],
#        [-0.49001441, -1.30738606, -1.74236807, ...,  0.04646282,
#         -0.34070198,  0.91093523],
#        [-0.34698051,  1.2789064 , -1.06431292, ...,  0.4068325 ,
#          0.075357  ,  0.5343899 ],
#        ...,
#        [ 0.89462135, -0.84697797,  1.41455858, ...,  0.15640886,
#          1.66214466,  0.09608005],
#        [-0.02817655, -0.34770488,  0.92394892, ...,  1.58638017,
#         -0.01371618,  0.05301875],
#        [ 0.74480555,  0.14838763,  0.09077492, ..., -1.32078478,
#         -0.07851031, -1.09953177]])

# %%
df_dna_scaled.shape
# Out:
# (712, 185466)

# %% [markdown]
# PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=500)

# %%
Principal_components=pca.fit_transform(df_dna_scaled)

# %%
Principal_components.shape
# Out:
# (712, 500)

# %%
pca_df = pd.DataFrame(data = Principal_components)
print(pca_df)
# Out:
#             0           1          2           3          4          5    \
# 0     36.600111  -12.275717 -84.734661  -32.307612 -34.222749  12.691366
# 1   -114.910520   85.092677 -12.408808   24.201791 -22.191433   1.553270
# 2    106.688871  -85.437241   8.180619  -61.183764  -9.667788  13.617953
# 3     87.908674  -73.983673  35.070780 -100.270869 -24.780582 -25.897072
# 4   -117.118412  -44.425893  23.589971   35.392429 -17.343847  -9.766743
# ..          ...         ...        ...         ...        ...        ...
# 707  -71.796703  -89.088230 -19.127152   -2.567339   4.089957 -11.317746
# 708 -112.768257   -1.906566  45.092536   38.481578  11.532611   4.104808
# 709  174.926364   10.118947  24.879660   13.868267 -74.507306 -34.145191
# 710  132.873826 -100.938927  44.633575   -2.341168  38.399852  -5.995786
# 711    3.519817   37.786181 -56.814606   36.592808 -12.122841 -40.812018
#
#            6          7          8          9    ...        490       491  \
# 0    -0.443720  -1.363513   9.172199  -6.324253  ...   0.026595 -0.483480
# 1     1.799835  12.692766  -5.963727  -8.730676  ...   2.328613 -2.094549
# 2   -11.717036  -0.414039  -3.900910 -16.433895  ...   0.255427  1.319321
# 3     9.685326   5.464969  22.772950   0.802133  ...  11.906656 -1.125725
# 4    -2.255174  31.950299 -16.799401  12.046989  ...   2.863550  0.019195
# ..         ...        ...        ...        ...  ...        ...       ...
# 707   5.275722  14.034123   3.431795   0.638752  ...   0.270951 -0.282950
# 708  -0.707871  -8.987174  -4.527386  -0.213166  ...   6.323479 -3.553927
# 709  -6.643544  81.093841 -45.539886 -35.111434  ...  -1.489104 -1.939295
# 710   9.929458 -33.468783  -5.498729  31.287152  ...  -1.886729 -0.821391
# 711  15.428159  -9.374108  19.098075   3.763876  ...   0.552387  0.113485
#
#           492       493       494       495       496       497       498  \
# 0    0.120645  1.313669  1.520597  1.857257  2.512165 -0.094364  0.078613
# 1   -2.748291  7.926897 -7.983261  8.966411  5.684373  0.849786  1.398287
# 2    0.499406 -0.992166  0.466953 -1.559320 -1.451588 -0.253943  0.203269
# 3    2.461040 -4.893131  3.513222 -5.290533  1.039969 -0.024054 -0.982378
# 4   -1.605945 -0.660369  0.136944  0.735846  0.684318  0.094835 -0.732313
# ..        ...       ...       ...       ...       ...       ...       ...
# 707  1.320262  1.142744 -0.282360  1.437232  2.140991 -1.324738 -0.692464
# 708  0.237161  0.474200 -1.789020 -5.575379 -3.171117  2.428700  2.766763
# 709 -0.248974  0.641911 -1.212114 -0.621050 -1.203595 -0.397063  0.193187
# 710  0.208405  0.194248 -5.618124  0.966769 -0.201254  0.128884  0.469927
# 711 -0.149127  0.820104  3.928017 -2.634853 -2.045538 -0.396332  0.286020
#
#               499
# 0    3.035725e-08
# 1    2.565677e-14
# 2    4.314760e-07
# 3    5.012494e-15
# 4    4.258002e-07
# ..            ...
# 707  3.010238e-06
# 708  1.686970e-15
# 709 -3.602016e-06
# 710 -3.077879e-06
# 711 -1.525651e-06
#
# [712 rows x 500 columns]

# %%
pca.n_samples_, pca.n_features_
# Out:
# (712, 185466)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('
#  0.94874581 0.94952289 0.95029768 0.95106954 0.95183917 0.95260695
#  0.95337182 0.9541343  0.95488989 0.95564302 0.95639471 0.95714514
#  0.95789256 0.95863587 0.95937321 0.96011009 0.9608435  0.96157172
#  0.96229594 0.96301791 0.96373413 0.96444888 0.96516255 0.96587335
#  0.96658002 0.96728578 0.96798967 0.9686913  0.96938946 0.97008607
#  0.97077879 0.97146802 0.97215443 0.97283931 0.97351974 0.97419711
#  0.97487367 0.97554745 0.97621944 0.97688667 0.97755161 0.97821613
#  0.97887542 0.9795319  0.98018628 0.98083823 0.98148516 0.98213128
#  0.98277583 0.98341599 0.98405369 0.98468856 0.98531943 0.98594844
#  0.98657494 0.98719782 0.98781803 0.98843618 0.98905249 0.98966688
#  0.99028014 0.99089108 0.99149926 0.99210428 0.99270736 0.99330529
#  0.99389641 0.99447852 0.99505304 0.99561838 0.99617842 0.99673418
#  0.9972734  0.99780513 0.99830133 0.99878631 0.99924768 0.99963885
#  1.         1.        ]

# %% [markdown]
# **PCA Reconstruction back to original dimensions**

# %%
projected_data = pca.inverse_transform(Principal_components)

# %%
projected_data.shape
# Out:
# (712, 185466)

# %%
df_dna_scaled
# Out:
# array([[ 0.15198498,  0.8536411 , -0.35346204, ...,  0.17362116,
#         -0.89931176, -1.58306336],
#        [-0.49001441, -1.30738606, -1.74236807, ...,  0.04646282,
#         -0.34070198,  0.91093523],
#        [-0.34698051,  1.2789064 , -1.06431292, ...,  0.4068325 ,
#          0.075357  ,  0.5343899 ],
#        ...,
#        [ 0.89462135, -0.84697797,  1.41455858, ...,  0.15640886,
#          1.66214466,  0.09608005],
#        [-0.02817655, -0.34770488,  0.92394892, ...,  1.58638017,
#         -0.01371618,  0.05301875],
#        [ 0.74480555,  0.14838763,  0.09077492, ..., -1.32078478,
#         -0.07851031, -1.09953177]])

# %%
projected_data
# Out:
# array([[ 0.15198499,  0.85364109, -0.35346204, ...,  0.17362115,
#         -0.89931176, -1.58306336],
#        [-0.49001441, -1.30738606, -1.74236807, ...,  0.04646282,
#         -0.34070198,  0.91093523],
#        [-0.3469805 ,  1.2789064 , -1.06431292, ...,  0.40683251,
#          0.075357  ,  0.5343899 ],
#        ...,
#        [ 0.89462135, -0.84697797,  1.41455858, ...,  0.15640886,
#          1.66214465,  0.09608005],
#        [-0.02817655, -0.34770487,  0.92394892, ...,  1.58638017,
#         -0.01371618,  0.05301875],
#        [ 0.74480555,  0.14838763,  0.09077492, ..., -1.32078478,
#         -0.07851031, -1.09953176]])

# %%
pca_df.shape
# Out:
# (712, 500)

# %%
reduced_dims = pca_df

# %%
reduced_dims.shape
# Out:
# (712, 500)

# %%
reduced_dims
# Out:
#             0           1          2           3          4          5    \
# 0     36.600111  -12.275717 -84.734661  -32.307612 -34.222749  12.691366
# 1   -114.910520   85.092677 -12.408808   24.201791 -22.191433   1.553270
# 2    106.688871  -85.437241   8.180619  -61.183764  -9.667788  13.617953
# 3     87.908674  -73.983673  35.070780 -100.270869 -24.780582 -25.897072
# 4   -117.118412  -44.425893  23.589971   35.392429 -17.343847  -9.766743
# ..          ...         ...        ...         ...        ...        ...
# 707  -71.796703  -89.088230 -19.127152   -2.567339   4.089957 -11.317746
# 708 -112.768257   -1.906566  45.092536   38.481578  11.532611   4.104808
# 709  174.926364   10.118947  24.879660   13.868267 -74.507306 -34.145191
# 710  132.873826 -100.938927  44.633575   -2.341168  38.399852  -5.995786
# 711    3.519817   37.786181 -56.814606   36.592808 -12.122841 -40.812018
#
#            6          7          8          9    ...        490       491  \
# 0    -0.443720  -1.363513   9.172199  -6.324253  ...   0.026595 -0.483480
# 1     1.799835  12.692766  -5.963727  -8.730676  ...   2.328613 -2.094549
# 2   -11.717036  -0.414039  -3.900910 -16.433895  ...   0.255427  1.319321
# 3     9.685326   5.464969  22.772950   0.802133  ...  11.906656 -1.125725
# 4    -2.255174  31.950299 -16.799401  12.046989  ...   2.863550  0.019195
# ..         ...        ...        ...        ...  ...        ...       ...
# 707   5.275722  14.034123   3.431795   0.638752  ...   0.270951 -0.282950
# 708  -0.707871  -8.987174  -4.527386  -0.213166  ...   6.323479 -3.553927
# 709  -6.643544  81.093841 -45.539886 -35.111434  ...  -1.489104 -1.939295
# 710   9.929458 -33.468783  -5.498729  31.287152  ...  -1.886729 -0.821391
# 711  15.428159  -9.374108  19.098075   3.763876  ...   0.552387  0.113485
#
#           492       493       494       495       496       497       498  \
# 0    0.120645  1.313669  1.520597  1.857257  2.512165 -0.094364  0.078613
# 1   -2.748291  7.926897 -7.983261  8.966411  5.684373  0.849786  1.398287
# 2    0.499406 -0.992166  0.466953 -1.559320 -1.451588 -0.253943  0.203269
# 3    2.461040 -4.893131  3.513222 -5.290533  1.039969 -0.024054 -0.982378
# 4   -1.605945 -0.660369  0.136944  0.735846  0.684318  0.094835 -0.732313
# ..        ...       ...       ...       ...       ...       ...       ...
# 707  1.320262  1.142744 -0.282360  1.437232  2.140991 -1.324738 -0.692464
# 708  0.237161  0.474200 -1.789020 -5.575379 -3.171117  2.428700  2.766763
# 709 -0.248974  0.641911 -1.212114 -0.621050 -1.203595 -0.397063  0.193187
# 710  0.208405  0.194248 -5.618124  0.966769 -0.201254  0.128884  0.469927
# 711 -0.149127  0.820104  3.928017 -2.634853 -2.045538 -0.396332  0.286020
#
#               499
# 0    3.035725e-08
# 1    2.565677e-14
# 2    4.314760e-07
# 3    5.012494e-15
# 4    4.258002e-07
# ..            ...
# 707  3.010238e-06
# 708  1.686970e-15
# 709 -3.602016e-06
# 710 -3.077879e-06
# 711 -1.525651e-06
#
# [712 rows x 500 columns]

# %%
### Reading the betaindex files..

intial_betaindex = pd.read_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/smok_MG_20210218_betaindex.csv')
new_betaindex = pd.read_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/smok_MG_20211006_betaindex.csv')

# %%
new_betaindex.loc[:,'x'] += 5000

# %%
combined_betaindex = intial_betaindex.append(new_betaindex)

# %%
combined_betaindex[330: 350]
# Out:
#         x
# 330  4922
# 331  4933
# 332  4941
# 333  4943
# 334  4946
# 335  4967
# 336  4972
# 337  4981
# 338  4984
# 339  4999
# 0    5004
# 1    5024
# 2    5025
# 3    5028
# 4    5058
# 5    5064
# 6    5071
# 7    5084
# 8    5128
# 9    5163

# %%
combined_betaindex.to_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/combined_beta_index.csv', index=False)

# %%
# Import the corresponding rows indexs for the health outcomes files.

df_index = pd.read_csv('/project/6043799/mohan235/1_Mohan_GRAF_Work/combined_beta_index.csv', header=None)

# %%
df_index
# Out:
#         0
# 0       x
# 1       4
# 2      17
# 3      21
# 4      32
# ..    ...
# 708  9948
# 709  9966
# 710  9979
# 711  9980
# 712  9997
#
# [713 rows x 1 columns]

# %%
df_index = df_index.iloc[1:, :]

df_index
# Out:
#         0
# 1       4
# 2      17
# 3      21
# 4      32
# 5      51
# ..    ...
# 708  9948
# 709  9966
# 710  9979
# 711  9980
# 712  9997
#
# [712 rows x 1 columns]

# %%
indexes = df_index.to_numpy()

# %%
indexes.shape
# Out:
# (712, 1)

# %%
indexes = indexes.reshape(1, 712)

# %%
indexes = indexes[0][:]

# %%
all_indexes = []
for x in indexes:
  all_indexes.append(int(x))

print(all_indexes)
# Out:
# [4, 17, 21, 32, 51, 58, 61, 63, 66, 104, 128, 152, 166, 169, 170, 173, 178, 189, 193, 201, 205, 216, 227, 242, 243, 306, 340, 348, 367, 405, 413, 415, 425, 438, 461, 478, 534, 537, 563, 576, 595, 606, 629, 634, 655, 680, 696, 701, 704, 728, 744, 748, 764, 780, 784, 816, 842, 871, 875, 891, 903, 919, 925, 936, 960, 977, 1015, 1031, 1040, 1043, 1053, 1070, 1076, 1091, 1098, 1112, 1113, 1127, 1152, 1153, 1154, 1155, 1157, 1179, 1194, 1200, 1201, 1231, 1236, 1255, 1265, 1278, 1281, 1286, 1288, 1295, 1298, 1321, 1335, 1337, 1364, 1381, 1395, 1402, 1418, 1435, 1444, 1464, 1489, 1527, 1534, 1551, 1564, 1592, 1617, 1636, 1670, 1713, 1736, 1756, 1770, 1787, 1794, 1802, 1829, 1859, 1900, 1934, 1941, 1952, 1978, 1981, 1997, 2018, 2023, 2128, 2132, 2184, 2193, 2201, 2202, 2219, 2241, 2244, 2253, 2266, 2297, 2311, 2315, 2320, 2341, 2343, 2369, 2376, 2404, 2409, 2423, 2472, 2535, 2553, 2565, 2572, 2618, 2623, 2627, 2644, 2649, 2650, 2660, 2692, 2694, 2711, 2732, 2746, 2755, 2766, 2789, 2801, 2805, 2813, 2819, 2820, 2824, 2826, 2828, 2840, 2848, 2884, 2893, 2896, 2903, 2907, 2943, 2958, 2963, 2970, 2982, 2992, 2998, 3006, 3034, 3071, 3097, 3114, 3115, 3168, 3174, 3212, 3220, 3228, 3247, 3253, 3293, 3296, 3299, 3308, 3338, 3340, 3365, 3366, 3390, 3426, 3448, 3450, 3463, 3477, 3490, 3497, 3525, 3542, 3553, 3559, 3561, 3566, 3587, 3614, 3632, 3634, 3636, 3642, 3648, 3649, 3675, 3678, 3681, 3724, 3725, 3742, 3770, 3778, 3782, 3792
8810, 8831, 8867, 8868, 8870, 8894, 8949, 8957, 8969, 8973, 8996, 9023, 9031, 9052, 9055, 9059, 9070, 9076, 9106, 9119, 9137, 9156, 9180, 9202, 9221, 9226, 9228, 9231, 9242, 9243, 9259, 9292, 9299, 9327, 9354, 9361, 9383, 9450, 9461, 9469, 9488, 9490, 9495, 9523, 9587, 9590, 9594, 9 ...

# %%
# Import survey and health outcomes data

patterns = ['G:A', 'C:C', 'T:T', 'T:A', 'A:T', 'G:G', 'C:T', 'A:A', ' A:A', 'T:C', 'T:G']
mGST = ['Heterozygote', 'Gene present', 'Null genotype', 'Wild type - no deletion']
AQ = ['Incomplete', 'Complete']
AR = ['Singleton', 'Twin']
qlet = ['A', 'B']
sex = ['Male', 'Female']

# %%
import csv
source = open("/project/6043799/mohan235/1_Mohan_GRAF_Work/complete_10k_rows_v2a.csv", "r")
source_reader = csv.reader(x.replace('\0', '') for x in source)

# %%
complete_rows = []

#Grabbing all rows

count = 0
for i, row in enumerate(source_reader):
  if i in all_indexes:
    print("The row is:", row)
    row_input_data = row
    complete_rows.append(row[44:88])
    count+= 1
source.close()

print("COunt is:", count)
# print("complet rows are:", complete_rows)
# complete_rows.pop(0)
# Out:
# The row is: ['A', 'G:A', 'C:C', 'G:A', 'T:T', 'T:A', 'C:C', 'A:T', 'Heterozygote', 'Gene present', 'Null genotype', 'Null genotype', 'T:T', ' A:A', 'T:T', 'T:T', 'A:T', 'C:T', 'C:C', '9', '22.78937555', '2', '32', '0.289786905', '0', '2', '36.2', '52.3', '40', '1', '2.150280294', '0', '2', '1', '1', '1', '1', '2', '3', '0', '0', '0', 'Complete', 'Singleton', '0.633069515', '0.920050383', '1.238199592', '-0.034310721', '-0.790380657', '0.594326258', '-0.554883599', '0.407413721', '-0.296603739', '-0.221100658', '-0.458865924', '-0.167541709', '0.205402829', '-0.19275476', '0.269178676', '-0.189069152', '0.044115072', '0.725664881', '0.022703768', '-0.432274353', '1.676604267', '0.553079937', '0.5426776', '0.238346921', '0.364685344', '-0.061751407', '1.01286905', '-0.390738903', '-0.072858897', '-0.238755923', '-0.20111182', '-0.329788097', '0.938802999', '0.668474751', '-0.263255753', '-0.745514993', '0.444936876', '-0.988864472', '-0.690973565', '-0.398748699', '-0.225743512', '-0.71893335', '-0.250973312', '-0.462490042', 'Female', '0.093644714', '0.193399637', '0.056388832', '0.41656052', '0.118169223', '0.097094867', '0.060612043']
# The row is: ['A', 'G:A', 'C:C', 'G:A', 'T:T', 'T:A', 'C:C', 'A:T', 'Wild type - no deletion', 'Gene present', 'Null genotype', 'Null genotype', 'T:T', ' A:A', 'T:T', 'T:T', ' A:A', 'C:C', 'C:C', '11', '23.09388783', '2', '24', '0.409470797', '0', '1', 'NA', 'NA', '38', '1', '0.06068575', '0', '2', '1', '1', '1', '1', '2', '2', '0', '0', '0', 'Incomplete', 'Singleton', '-0.562015831', '0.51652652', '0.266617924', '0.472320467', '-0.025318708', '-1.068994761', '-0.41458714', '0.803593576', '0.119608231', '-0.516864598', '-0.282861803', '0.192672889', '0.761999977', '0.454404106', '-0.028076808', '-0.874648416', '-0.529027208', '-0.771073018', '0.350780206', '0.343878762', '-0.059035154', '-0.037865464', '-0.365897283', '-0.549262918', '-0.370231089', '-0.505422205', '-0.494864566', '0.096092271', '-0.176788279', '-0.469164397', '-0.312000149', '-0.296921849', '-0.645654824', '-0.057634495', '0.594157232', '0.987454152', '0.793081261', '0.342754533', '-0.402892943', '-0.273098762', '-0.169870216', '-0.5492946', '-0.870054196', '-0.489782686', 'Male', '0.035113876', '0.239885642', '0.101875413', '0.295076085', '0.095157709', '0.035546811', '0.223446908']
# The row is: ['A', 'G:G', 'C:C', 'A:A', 
672908423', '2.810516479', '2.365523177', '1.745399735', '2.060810405', '2.057427003', '1.803887764', '1.463149494', '1.547067587', '0.384573905', '-0.162321386', '-0.263913421', '-0.533325086', '1.383687839', '1.503411013', '1.092810715', '0.505961813', '1.102852162', '1.729638878', '0.629957899', 'Male', '0.109095717', '0.219235449', '0.078750802', '0.361691246', '0.13354582', '0.08623809', '0.057629403']
# COunt is: 712

# %%
print("Total rows is:", count)
# Out:
# Total rows is: 712

# %%
for row in complete_rows:
    for i in range(0, len(row)):
        current_pattern = row[i]
        if row[i] in patterns:
            row[i] = patterns.index(current_pattern)

        elif row[i] in mGST:
            row[i] = mGST.index(current_pattern)

        elif row[i] in AQ:
            row[i] = AQ.index(current_pattern)

        elif row[i] in AR:
            row[i] = AR.index(current_pattern)
        elif row[i] in sex:
            row[i] = sex.index(current_pattern)

# %%
print(len(complete_rows))
# Out:
# 712

# %%
count = 0
for row in complete_rows:
    if('NA' not in row):
      count+= 1
      for i in range(0, len(row)):
        row[i] = float(row[i])

# %%
print('The number of non-zero rows:', count)
# Out:
# The number of non-zero rows: 501

# %%
non_na_rows = []
remove_index = []
for i, row in enumerate(complete_rows):
  if('NA' not in row):
    non_na_rows.append(row)
  else:
    remove_index.append(i)

# %%
len(non_na_rows), len(remove_index)
# Out:
# (501, 211)

# %%
non_na_rows = np.array(non_na_rows)

# %%
non_na_rows.shape
# Out:
# (501, 44)

# %%
### Now remove the 'NA' values from AutoEncoder compressed data and health outcomes.

# %%
reduced_dims.shape
# Out:
# (712, 500)

# %%
pca_df = reduced_dims

# %%
pca_df = pca_df.to_numpy()

# %%
pca_df
# Out:
# array([[ 3.66001107e+01, -1.22757169e+01, -8.47346610e+01, ...,
#         -9.43639433e-02,  7.86125762e-02,  3.03572496e-08],
#        [-1.14910520e+02,  8.50926772e+01, -1.24088080e+01, ...,
#          8.49785962e-01,  1.39828714e+00,  2.56567700e-14],
#        [ 1.06688871e+02, -8.54372414e+01,  8.18061932e+00, ...,
#         -2.53943365e-01,  2.03268552e-01,  4.31476048e-07],
#        ...,
#        [ 1.74926364e+02,  1.01189466e+01,  2.48796600e+01, ...,
#         -3.97062847e-01,  1.93186686e-01, -3.60201644e-06],
#        [ 1.32873826e+02, -1.00938927e+02,  4.46335752e+01, ...,
#          1.28883959e-01,  4.69926902e-01, -3.07787872e-06],
#        [ 3.51981689e+00,  3.77861807e+01, -5.68146060e+01, ...,
#         -3.96332232e-01,  2.86020043e-01, -1.52565129e-06]])

# %%
pca_df.shape
# Out:
# (712, 500)

# %%
filtered_pca =[]
for i, row in enumerate(pca_df):
  if i not in remove_index:
    filtered_pca.append(row)

# %%
len(filtered_pca)
# Out:
# 501

# %%
filtered_pca = np.array(filtered_pca)

# %%
filtered_pca.shape
# Out:
# (501, 500)

# %%
non_na_rows.shape
# Out:
# (501, 44)

# %%
#Remove the duplicated rows

filtered_pca = filtered_pca.tolist()
non_na_rows = non_na_rows.tolist()

# %%
clubbed = [(x, y) for n, (x, y) in enumerate(zip(filtered_pca, non_na_rows)) if y not in non_na_rows[:n]]

# %%
filtered_pca_1 = np.array([x for (x, y) in clubbed])
non_na_rows_1 = np.array([y for (x, y) in clubbed])

# %%
filtered_pca_1.shape,  non_na_rows_1.shape
# Out:
# ((349, 500), (349, 44))

# %% [markdown]
# Create New embedding after removing important indices for sex+cell count!

# %%
## The delete index positions are from the previous notebook
### Change the values here.....
new_delete_positions = [459, 465, 467, 468, 470, 474, 478, 486, 487, 489, 492, 493, 497]

filtered_pca_1 = np.delete(filtered_pca_1, new_delete_positions, axis=1)

# %%
# split the train and the test data
x_train = filtered_pca_1[:310]
x_test = filtered_pca_1[-38:]

y_train = non_na_rows_1[:310]
y_test = non_na_rows_1[-38:]
print("X train data shape is: ", x_train.shape)
print("Y train data shape is: ", y_train.shape)
print("X test data shape is: ", x_test.shape)
print("Y test data shape is: ", y_test.shape)
# Out:
# X train data shape is:  (310, 487)
# Y train data shape is:  (310, 44)
# X test data shape is:  (38, 487)
# Y test data shape is:  (38, 44)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (310, 487, 1)
# (310, 44, 1)
# (38, 487, 1)
# (38, 44, 1)

# %%
import csv
import pandas as pd
import pickle
import numpy as np
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers import Bidirectional
from tensorflow.keras import optimizers
import re
import random
import scipy.stats
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import tensorflow as tf

import numpy as np
import random
import tensorflow as tf

np.random.seed(1)
random.seed(1)
tf.random.set_seed(1)

# %%
#Change the input index....
model = Sequential()
model.add(LSTM(units = 512, return_sequences = True, input_shape = (487, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 512, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 512, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 512))
model.add(Dropout(0.2))
model.add(Dense(units = 44))
# Out:
# 2021-12-11 19:56:12.007132: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-11 19:56:13.651829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11323 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:04:00.0, compute capability: 6.0

# %%
adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.load_weights('run3_v2a_combined_10k_model_new_embeddings_DNA_to_health_outcomes_LSTM.h5', by_name=True, skip_mismatch=True)
model.compile(optimizer = adam, loss = 'mean_squared_error')
# model.summary()
# Out:
# /home/mohan235/jupyter_py3/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
scores = model.evaluate(x_test, y_test, verbose=2)
print("MSE, MSE on test set:")
print(scores)
# Out:
# 2021-12-11 19:56:37.794585: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-11 19:56:40.975673: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8200
# 2/2 - 4s - loss: 0.9676
# MSE, MSE on test set:
# 0.9675993919372559

# %%
for i, layer in enumerate(model.get_weights()):
    print(model.get_weights()[i].shape)
# Out:
# (1, 2048)
# (512, 2048)
# (2048,)
# (512, 2048)
# (512, 2048)
# (2048,)
# (512, 2048)
# (512, 2048)
# (2048,)
# (512, 2048)
# (512, 2048)
# (2048,)
# (512, 44)
# (44,)

# %%
### Conceptual expansion mutation version. Multiplying alpha by random number in range [-2, 2] for a layer.

def mutation_1(model_1, alphas):
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy() 
    model_alphas = alphas.copy()
    ## To get the ture values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    layer_index = random.randint(1, len(model_weights)-1)
    current_layer = model.get_weights()[layer_index]
    
    loaded_model = tf.keras.models.clone_model(model)
    
    print("Mutaion operation X where multiplying alpha with random range for a layer")
#     print("The model layer: ", layer_index)
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.uniform(-2, 2, size=(x_index, y_index))
        model_alphas[layer_index] = np.multiply(model_alphas[layer_index],x)
    elif len(current_layer.shape) == 1:
        x_index = current_layer.shape[0]
        x = np.random.uniform(-2, 2, size=x_index)
        model_alphas[layer_index] = np.multiply(model_alphas[layer_index],x)
    
    ### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
### Conceptual expansion mutation version. replaces f values of a random layer with a randomly selected f values

def mutation_2(model_1, alphas):
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy() 
    model_alphas = alphas.copy()
    ## To get the ture values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    ### source layer index
#     layer_index = random.randint(0, len(model_weights)-1)
    source_index = random.choice([i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2])
    
#     for index in range(len(model_weights)):
#         print("The shape and len of model weights in layer is:",model_weights[index].shape, len(model_weights[index].shape))
    
#     print("The target index list is:", [i for i in range(1, len(model_weights)-1) if len(model_weights[i].shape)==2].remove(source_index), "indes is ", source_index)
    ### target layer index
    valid_indices= [i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2]
    valid_indices.remove(source_index)
    target_index = random.choice(valid_indices)
    print(f" Replacing values in target index {source_index} from the source index is {target_index}")
    
    ### Since all the weights are in same shape for the 2D data, we can directly replace the values. 
    model_weights[target_index] = model_weights[source_index]
    
    loaded_model = tf.keras.models.clone_model(model)
    
    ### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
### Conceptual expansion mutation version. add a random a and f to a random position in a random layer.

def mutation_3(model_1, alphas):
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy() 
    model_alphas = alphas.copy()
    ## To get the ture values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    ### source layer index
#     layer_index = random.randint(0, len(model_weights)-1)
    source_index = random.choice([i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2])
    ### target layer index
    valid_indices= [i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2]
    valid_indices.remove(source_index)
    target_index = random.choice(valid_indices)
#     target_index = random.choice([i for i in range(1, len(model_weights)-1) if len(model_weights[i].shape)==2].remove(source_index))
    print(f" Replacing values in Adding target index{source_index} to the source index is {target_index}")
    
    ### Since all the weights are in same shape for the 2D data, we can directly replace the values. 
    model_weights[target_index] = model_weights[target_index] + model_weights[source_index]
    model_alphas[target_index] = model_alphas[target_index] + model_alphas[source_index]
    
    loaded_model = tf.keras.models.clone_model(model)
    
    ### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
### Conceptual expansion mutation version. swapping two random layers with 'f' and 'a'

def mutation_4(model_1, alphas):
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy() 
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    ### source layer index
#     layer_index = random.randint(0, len(model_weights)-1)
    source_index = random.choice([i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2])
    ### target layer index
    valid_indices= [i for i in range(1, len(model_weights)-2) if len(model_weights[i].shape)==2]
    valid_indices.remove(source_index)
    target_index = random.choice(valid_indices)
#     target_index = random.choice([i for i in range(1, len(model_weights)-1) if len(model_weights[i].shape)==2].remove(source_index))
    print(f" Swapping values at target index {source_index} and source index is {target_index}")
    
    ### Since all the weights are in same shape for the 2D data, we can directly swap without reshaping them.
    model_weights[source_index], model_weights[target_index] = model_weights[target_index],model_weights[source_index]
    
    model_alphas[source_index], model_alphas[target_index] = model_alphas[target_index], model_alphas[source_index]
    
    loaded_model = tf.keras.models.clone_model(model)
    
    ### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Add weights to a particular muataion index
from keras.models import model_from_json

def mutation_only_weights_1(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 1! - Adding to an index')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_weights[weights_index][x_index][y_index] = model_weights[weights_index][x_index][y_index] + x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_weights[weights_index][x_index] = model_weights[weights_index][x_index] + x
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index][y_index] = model_alphas[weights_index][x_index][y_index] + x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index] = model_alphas[weights_index][x_index] + x
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Add weights to a particular muatation layer
from keras.models import model_from_json

def mutation_only_weights_2(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 2! - Adding to an layer')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     print("The model weights shape is:", model_weights[weights_index].shape, )
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_weights[weights_index] = np.add(model_weights[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_weights[weights_index] = np.add(model_weights[weights_index], x)
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_alphas[weights_index] = np.add(model_alphas[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_alphas[weights_index] = np.add(model_alphas[weights_index], x)
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Subtracting weights to a particular muataion index
from keras.models import model_from_json

def mutation_only_weights_3(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 3! - Subtracting to an index')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_weights[weights_index][x_index][y_index] = model_weights[weights_index][x_index][y_index] - x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_weights[weights_index][x_index] = model_weights[weights_index][x_index] - x
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index][y_index] = model_alphas[weights_index][x_index][y_index] - x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index] = model_alphas[weights_index][x_index] - x
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Subtracting weights to a particular muataion layer
from keras.models import model_from_json

def mutation_only_weights_4(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 4! - Subtracting to an layer')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_weights[weights_index] = np.subtract(model_weights[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_weights[weights_index] = np.subtract(model_weights[weights_index], x)
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_alphas[weights_index] = np.subtract(model_alphas[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_alphas[weights_index] = np.subtract(model_alphas[weights_index], x)
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Multiplying weights to a particular muataion index
from keras.models import model_from_json

def mutation_only_weights_5(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 5! - Multiplying to an index')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_weights[weights_index][x_index][y_index] = model_weights[weights_index][x_index][y_index] * x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_weights[weights_index][x_index] = model_weights[weights_index][x_index] * x
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index][y_index] = model_alphas[weights_index][x_index][y_index] * x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index] = model_alphas[weights_index][x_index] * x
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Multiplying weights to a particular muataion layer
from keras.models import model_from_json

def mutation_only_weights_6(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 6! - Multiplying to an layer')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_weights[weights_index] = np.multiply(model_weights[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_weights[weights_index] = np.multiply(model_weights[weights_index], x)
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_alphas[weights_index] = np.multiply(model_alphas[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_alphas[weights_index] = np.multiply(model_alphas[weights_index], x)
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Divide weights to a particular muataion index
from keras.models import model_from_json

def mutation_only_weights_7(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 7! - Dividing to an index')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_weights[weights_index][x_index][y_index] = model_weights[weights_index][x_index][y_index] / x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_weights[weights_index][x_index] = model_weights[weights_index][x_index] / x
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = random.randint(0, current_layer.shape[0]-1)
        y_index = random.randint(0, current_layer.shape[1]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index][y_index] = model_alphas[weights_index][x_index][y_index] / x
    elif len(current_layer.shape) ==1:
        x_index = random.randint(0, current_layer.shape[0]-1)
        x = np.random.random()
        model_alphas[weights_index][x_index] = model_alphas[weights_index][x_index] / x
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
# Divide weights to a particular muataion layer
from keras.models import model_from_json

def mutation_only_weights_8(model_1, alphas):
    #deifne weights
    print('Applying Weights only Mutation 8! - Dividing to an layer')
    model = model_1
    model_weights_1 = model.get_weights()
    model_weights = model_weights_1.copy()
    model_alphas = alphas.copy()
    ## To get the true values of the weights i.e. by dividing with alpha values.. Since we are multiplying the weights with alphas in the end
    for index in range(len(model_weights)):
        model_weights[index] = np.divide(model_weights[index], model_alphas[index])
    
    weights_index = random.randint(0, len(model_weights)-1)
    current_layer = model.get_weights()[weights_index]
    
#     json_file = open('base_model.json', 'r')
#     loaded_model_json = json_file.read()
#     json_file.close()
#     loaded_model = model_from_json(loaded_model_json)

    loaded_model = tf.keras.models.clone_model(model)
#     print(loaded_model.get_weights()[-1].shape)
    
    ###For weights
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_weights[weights_index] = np.divide(model_weights[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_weights[weights_index] = np.divide(model_weights[weights_index], x)
    
    ### For alpha values
    if len(current_layer.shape) ==2:
        x_index = current_layer.shape[0]
        y_index = current_layer.shape[1]
        x = np.random.random((x_index, y_index))
        model_alphas[weights_index] = np.divide(model_alphas[weights_index], x)
    elif len(current_layer.shape) ==1:
        x_index = current_layer.shape[0]
        x = np.random.random(x_index)
        model_alphas[weights_index] = np.divide(model_alphas[weights_index], x)
    
    #### Multiply the weights with alpha values.
    for index in range(len(model_weights)):
        model_weights[index] = np.multiply(model_weights[index], model_alphas[index])
    
    adam = optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    loaded_model.set_weights(model_weights)
    loaded_model.compile(optimizer = adam, loss = 'mean_squared_error')
    return loaded_model, model_alphas

# %%
from keras.models import model_from_json

# %%
### Mutation functions

### Conceptual expansion mutation operations

def CE_mutation(model, alpha):
    x = random.randint(1, 4)
    if(x==1):
        model_1, alpha_1 = mutation_1(model, alpha)
    elif(x==2):
        model_1, alpha_1 = mutation_2(model, alpha)
    elif(x==3):
        model_1, alpha_1 = mutation_3(model, alpha)
    elif(x==4):
        model_1, alpha_1 = mutation_4(model, alpha)
    
    return model_1, alpha_1del

# %%
### Mutation functions

### Weights only mutation operations


def weights_mutation(model, alpha):
    x = random.randint(1, 8)
    if(x==1):
        model_1, alpha_1 = mutation_only_weights_1(model, alpha)
    elif(x==2):
        model_1, alpha_1 = mutation_only_weights_2(model, alpha)
    elif(x==3):
        model_1, alpha_1 = mutation_only_weights_3(model, alpha)
    elif(x==4):
        model_1, alpha_1 = mutation_only_weights_4(model, alpha)
    elif(x==5):
        model_1, alpha_1 = mutation_only_weights_5(model, alpha)
    elif(x==6):
        model_1, alpha_1 = mutation_only_weights_6(model, alpha)
    elif(x==7):
        model_1, alpha_1 = mutation_only_weights_7(model, alpha)
    elif(x==8):
        model_1, alpha_1 = mutation_only_weights_8(model, alpha)
    
    return model_1, alpha_1, x

# %%
### Mutation functions

### Weights only mutation operations


def combined_mutation(model, alpha):
    x = random.randint(1, 12)
    if(x==1):
        model_1, alpha_1 = mutation_only_weights_1(model, alpha)
    elif(x==2):
        model_1, alpha_1 = mutation_only_weights_2(model, alpha)
    elif(x==3):
        model_1, alpha_1 = mutation_only_weights_3(model, alpha)
    elif(x==4):
        model_1, alpha_1 = mutation_only_weights_4(model, alpha)
    elif(x==5):
        model_1, alpha_1 = mutation_only_weights_5(model, alpha)
    elif(x==6):
        model_1, alpha_1 = mutation_only_weights_6(model, alpha)
    elif(x==7):
        model_1, alpha_1 = mutation_only_weights_7(model, alpha)
    elif(x==8):
        model_1, alpha_1 = mutation_only_weights_8(model, alpha)
    elif(x==9):
        model_1, alpha_1 = mutation_1(model, alpha)
    elif(x==10):
        model_1, alpha_1 = mutation_2(model, alpha)
    elif(x==11):
        model_1, alpha_1 = mutation_3(model, alpha)
    elif(x==12):
        model_1, alpha_1 = mutation_4(model, alpha)
    
    return model_1, alpha_1, x

# %%
# Returns the loss on the training data.
def fitness(model):
    return model.evaluate(x_train, y_train, verbose=2)

# %%
# Returns the loss on the testing data.
def test_loss(model):
    return model.evaluate(x_test, y_test, verbose=2)

# %% [markdown]
# Search Based on Weights based Mutation!

# %%
import os
iterations = 100
neighbours_count = 10
min_loss = 10e6

base_model = model
base_alphas = []
imp_mut_func = []
for layer in base_model.get_weights():
    alpha_layer = np.ones(layer.shape)
    base_alphas.append(alpha_layer)
for ix in range(iterations):
    # Generate 10 neighbours
    print(f"*************   Started the Iteration {ix}")  
    models = [base_model]
    models_alpha = [base_alphas]
    mutation_fun = []
    for j in range(0, neighbours_count-1):
        ## In each mutation function the alpha values will already be muliplied and the alpha values alone are also sepreately returned
        model_weightss, model_alpha, mut_func = weights_mutation(base_model, base_alphas)
        models.append(model_weightss)
        models_alpha.append(model_alpha)
        mutation_fun.append(mut_func)
    for i, (model_x, alphas) in enumerate(zip(models, models_alpha)):
        if fitness(model_x) < min_loss:
            min_loss = fitness(model_x)
            base_model = model_x
            base_alphas = models_alpha[i]
            imp_mut_func.append(mutation_fun[i-1])
    print(f"The minimum train loss in iteration {ix}:", min_loss, " The test loss is ", test_loss(base_model))
    print("The important mutation fucntions are:", imp_mut_func)
base_model.save("run3_best_model_Weights_in_CE_based_model_for_DNA_new_dimensions_to_health_outcomes_200_iterations.h5")
# Out:
# *************   Started the Iteration 0
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8601
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8370
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8566
# 10/10 - 4s - loss: 0.8252
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 0: 0.8133933544158936  The test loss is  0.9676008820533752
# The important mutation fucntions are: [4, 3]
# *************   Started the Iteration 1
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.9181
# 10/10 - 3s - loss: 1.3291
# 10/10 - 4s - loss: 0.9466
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8218
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8369
# 10/10 - 3s - loss: 0.8134
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 1: 0.8133926391601562  The test loss is  0.9676003456115723
# The important mutation fucntions are: [4, 3, 1]
# *************   Started the Iteration 2
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 1.1828
# 10/10 - 4s - loss: 4.5936
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.9055
# 10/10 - 4s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8198
# 10/10 - 3s - loss: 0.8479
# 10/10 - 3s - loss: 0.8134
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 2: 0.81339031457901  The test loss is  0.9675983786582947
# The important mutation fucntions are: [4, 3, 1, 1, 3]
# *************   Started the Iteration 3
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8137
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8181
# 10/10 - 3s - loss: 0.8367
# 10/10 - 4s - loss: 0.8318
# 10/10 - 3s - loss: 0.8137
# 10/10 - 3s - loss: 0.8136
# 10/10 - 4s - loss: 0.8191
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 3: 0.81339031457901  The test loss is  0.9675983786582947
# The important mutation fucntions are: [4, 3, 1, 1, 3]
# *************   Started the Iteration 4
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8135
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 1.0028
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8466
# 2/2 - 0s - loss: 0.9677
# The minimum train loss in iteration 4: 0.8133456110954285  The test loss is  0.9676852226257324
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3]
# *************   Started the Iteration 5
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8133
# 10/10 - 4s - loss: 0.8135
# 10/10 - 3s - loss: 0.9018
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8180
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8525
# 2/2 - 0s - loss: 0.9677
# The minimum train loss in iteration 5: 0.8133456110954285  The test loss is  0.9676852226257324
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3]
# *************   Started the Iteration 6
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8133
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8387
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8626
# 10/10 - 4s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 2/2 - 0s - loss: 0.9677
# The minimum train loss in iteration 6: 0.8133448958396912  The test loss is  0.9676802754402161
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1]
# *************   Started the Iteration 7
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8176
# 10/10 - 3s - loss: 0.8551
# 10/10 - 4s - loss: 0.8542
# 10/10 - 3s - loss: 0.8540
# 10/10 - 3s - loss: 0.8349
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8577
# 10/10 - 3s - loss: 0.8133
# 2/2 - 0s - loss: 0.9677
# The minimum train loss in iteration 7: 0.813335120677948  The test loss is  0.9676945209503174
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5]
# *************   Started the Iteration 8
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8133
# 10/10 - 4s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 1.3983
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8577
# 10/10 - 3s - loss: 0.9114
# 2/2 - 0s - loss: 0.9677
# The minimum train loss in iteration 8: 0.8133325576782227  The test loss is  0.9676950573921204
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1]
# *************   Started the Iteration 9
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8323
# 10/10 - 4s - loss: 0.8133
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8373
# 10/10 - 4s - loss: 0.8479
# 10/10 - 3s - loss: 0.8387
# 10/10 - 3s - loss: 1.0027
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8446
# 10/10 - 3s - loss: 0.8328
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 9: 0.8133032321929932  The test loss is  0.9680253267288208
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1]
# *************   Started the Iteration 10
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8133
# 10/10 - 4s - loss: 0.8576
# 10/10 - 4s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8430
# 10/10 - 3s - loss: 0.8492
# 10/10 - 4s - loss: 0.8551
# 10/10 - 3s - loss: 1.2153
# 10/10 - 3s - loss: 0.8483
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 10: 0.8133032321929932  The test loss is  0.9680253267288208
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1]
# *************   Started the Iteration 11
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8286
# 10/10 - 3s - loss: 0.8575
# 10/10 - 4s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8260
# 10/10 - 4s - loss: 1.4383
# 10/10 - 3s - loss: 0.8133
# 10/10 - 3s - loss: 0.8133
# 10/10 - 4s - loss: 0.8133
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 11: 0.8132074475288391  The test loss is  0.9679534435272217
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3]
# *************   Started the Iteration 12
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 2.3689
# 10/10 - 4s - loss: 128045336.0000
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 1.0041
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.8402
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 12: 0.8132074475288391  The test loss is  0.9679534435272217
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3]
# *************   Started the Iteration 13
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.9500
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8439
# 10/10 - 4s - loss: 0.8135
# 10/10 - 3s - loss: 0.8476
# 10/10 - 4s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 13: 0.8132047057151794  The test loss is  0.9679771065711975
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1]
# *************   Started the Iteration 14
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 1.1833
# 10/10 - 3s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 5.4428
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 1.2044
# 10/10 - 3s - loss: 1.0907
# 10/10 - 4s - loss: 0.8132
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 14: 0.8129817843437195  The test loss is  0.9666523337364197
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7]
# *************   Started the Iteration 15
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8556
# 10/10 - 3s - loss: 0.8529
# 10/10 - 3s - loss: 0.8411
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 0.8760
# 10/10 - 4s - loss: 4.6605
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 15: 0.8129817843437195  The test loss is  0.9666523337364197
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7]
# *************   Started the Iteration 16
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8502
# 10/10 - 3s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.8280
# 10/10 - 3s - loss: 0.8386
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.9012
# 10/10 - 3s - loss: 0.8317
# 10/10 - 4s - loss: 0.8130
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 16: 0.812978982925415  The test loss is  0.9666520357131958
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1]
# *************   Started the Iteration 17
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 1.0529
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.9475
# 10/10 - 3s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.9840
# 10/10 - 4s - loss: 0.8272
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 1.2044
# 10/10 - 4s - loss: 0.9342
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 17: 0.8129612803459167  The test loss is  0.966677188873291
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7]
# *************   Started the Iteration 18
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.8131
# 10/10 - 3s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8555
# 10/10 - 3s - loss: 0.8380
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 2.3689
# 10/10 - 3s - loss: 0.8399
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 18: 0.8129572868347168  The test loss is  0.9665428996086121
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5]
# *************   Started the Iteration 19
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 2s - loss: 0.8130
# 10/10 - 4s - loss: 0.8130
# 10/10 - 4s - loss: 0.8274
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.8226
# 10/10 - 3s - loss: 0.8426
# 10/10 - 3s - loss: 0.8965
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 19: 0.812957227230072  The test loss is  0.9665427207946777
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3]
# *************   Started the Iteration 20
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.8197
# 10/10 - 4s - loss: 0.8373
# 10/10 - 3s - loss: 1.2282
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.8265
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 0.8410
# 10/10 - 5s - loss: 0.8130
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 20: 0.812957227230072  The test loss is  0.9665427207946777
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3]
# *************   Started the Iteration 21
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8130
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8849
# 10/10 - 3s - loss: 0.8322
# 10/10 - 4s - loss: 0.8130
# 10/10 - 3s - loss: 0.8165
# 10/10 - 3s - loss: 0.8593
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 0.8168
# 10/10 - 3s - loss: 0.8130
# 2/2 - 0s - loss: 0.9655
# The minimum train loss in iteration 21: 0.8129289746284485  The test loss is  0.9654960632324219
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3]
# *************   Started the Iteration 22
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8645
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 2/2 - 0s - loss: 0.9658
# The minimum train loss in iteration 22: 0.8128904700279236  The test loss is  0.9658132791519165
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3]
# *************   Started the Iteration 23
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8506
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8142
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 1.3653
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8322
# 2/2 - 0s - loss: 0.9663
# The minimum train loss in iteration 23: 0.8128829002380371  The test loss is  0.966285228729248
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1]
# *************   Started the Iteration 24
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8279
# 10/10 - 4s - loss: 0.8145
# 10/10 - 3s - loss: 0.8129
# 2/2 - 0s - loss: 0.9662
# The minimum train loss in iteration 24: 0.8128796815872192  The test loss is  0.9662272930145264
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5]
# *************   Started the Iteration 25
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8231
# 10/10 - 4s - loss: 0.8278
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8269
# 10/10 - 4s - loss: 0.8214
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8221
# 2/2 - 0s - loss: 0.9662
# The minimum train loss in iteration 25: 0.81287682056427  The test loss is  0.9662453532218933
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1]
# *************   Started the Iteration 26
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8302
# 10/10 - 3s - loss: 0.8386
# 10/10 - 4s - loss: 1.2038
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8376
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 2/2 - 0s - loss: 0.9658
# The minimum train loss in iteration 26: 0.8128616213798523  The test loss is  0.9657890200614929
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1]
# *************   Started the Iteration 27
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8540
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8578
# 10/10 - 4s - loss: 1.1859
# 10/10 - 3s - loss: 0.8147
# 2/2 - 0s - loss: 0.9657
# The minimum train loss in iteration 27: 0.8128325939178467  The test loss is  0.965719997882843
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7]
# *************   Started the Iteration 28
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 1.3553
# 10/10 - 4s - loss: 0.8932
# 10/10 - 3s - loss: 2.0281
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8453
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9657
# The minimum train loss in iteration 28: 0.812828540802002  The test loss is  0.9657463431358337
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5]
# *************   Started the Iteration 29
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.9564
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 5596963.0000
# 10/10 - 3s - loss: 0.8382
# 10/10 - 3s - loss: 2567977.5000
# 10/10 - 3s - loss: 1.2035
# 2/2 - 0s - loss: 0.9657
# The minimum train loss in iteration 29: 0.8128283023834229  The test loss is  0.9657371044158936
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3]
# *************   Started the Iteration 30
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8738
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8297
# 10/10 - 3s - loss: 0.8582
# 10/10 - 3s - loss: 0.8534
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8385
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 30: 0.8127882480621338  The test loss is  0.9666441679000854
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7]
# *************   Started the Iteration 31
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8316
# 10/10 - 3s - loss: 1.3757
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.9281
# 10/10 - 3s - loss: 2.0528
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 31: 0.8127833008766174  The test loss is  0.9666946530342102
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7]
# *************   Started the Iteration 32
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 4s - loss: 1.1560
# 10/10 - 3s - loss: 0.9518
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 1.3937
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 1.0103
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 32: 0.8127833008766174  The test loss is  0.9666946530342102
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7]
# *************   Started the Iteration 33
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.9353
# 10/10 - 3s - loss: 0.8429
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8178
# 10/10 - 3s - loss: 0.8394
# 10/10 - 3s - loss: 0.8481
# 10/10 - 4s - loss: 0.8794
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 33: 0.8127832412719727  The test loss is  0.9666966795921326
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5]
# *************   Started the Iteration 34
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8309
# 10/10 - 3s - loss: 0.8497
# 10/10 - 4s - loss: 0.8576
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 2.3675
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9669
# The minimum train loss in iteration 34: 0.8127785921096802  The test loss is  0.9669205546379089
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3]
# *************   Started the Iteration 35
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8617
# 10/10 - 4s - loss: 0.8426
# 10/10 - 3s - loss: 0.8267
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8591
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8591
# 10/10 - 3s - loss: 0.8376
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 35: 0.8127626180648804  The test loss is  0.9666168689727783
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7]
# *************   Started the Iteration 36
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 2.3675
# 10/10 - 4s - loss: 0.8266
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8303
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.9191
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 36: 0.8127619624137878  The test loss is  0.9666212201118469
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1]
# *************   Started the Iteration 37
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8461
# 10/10 - 4s - loss: 0.8482
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8568
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 2.3675
# 10/10 - 4s - loss: 0.8144
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 1.1267
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 37: 0.8127617835998535  The test loss is  0.9666205048561096
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7]
# *************   Started the Iteration 38
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8723
# 10/10 - 4s - loss: 1.1841
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8372
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 38: 0.8127580881118774  The test loss is  0.9666348695755005
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3]
# *************   Started the Iteration 39
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8145
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8640
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8265
# 10/10 - 4s - loss: 0.8130
# 2/2 - 0s - loss: 0.9668
# The minimum train loss in iteration 39: 0.8127530813217163  The test loss is  0.966789960861206
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5]
# *************   Started the Iteration 40
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.9080
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8297
# 10/10 - 3s - loss: 1.1879
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8629
# 10/10 - 3s - loss: 0.8281
# 10/10 - 4s - loss: 0.8272
# 10/10 - 3s - loss: 1.3614
# 2/2 - 0s - loss: 0.9668
# The minimum train loss in iteration 40: 0.8127530813217163  The test loss is  0.966789960861206
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5]
# *************   Started the Iteration 41
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8915
# 10/10 - 4s - loss: 0.8342
# 10/10 - 3s - loss: 1.1743
# 10/10 - 4s - loss: 0.8419
# 10/10 - 3s - loss: 0.8534
# 10/10 - 3s - loss: 1.1611
# 10/10 - 4s - loss: 0.9541
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9668
# The minimum train loss in iteration 41: 0.8127530813217163  The test loss is  0.966789960861206
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5]
# *************   Started the Iteration 42
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 3s - loss: 0.8420
# 10/10 - 3s - loss: 1.2849
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8480
# 2/2 - 0s - loss: 0.9683
# The minimum train loss in iteration 42: 0.8127232789993286  The test loss is  0.9682849049568176
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3]
# *************   Started the Iteration 43
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8127
# 10/10 - 3s - loss: 1.0708
# 10/10 - 4s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 3s - loss: 1.3297
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8127
# 10/10 - 4s - loss: 0.8127
# 10/10 - 3s - loss: 0.8173
# 10/10 - 3s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8127
# 2/2 - 0s - loss: 0.9683
# The minimum train loss in iteration 43: 0.8127188682556152  The test loss is  0.9682954549789429
# ...
# *************   Started the Iteration 88
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 1.1883
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.9238
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8537
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8389
# 10/10 - 3s - loss: 0.8243
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9689
# The minimum train loss in iteration 88: 0.8124793767929077  The test loss is  0.9688754081726074
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1]
# *************   Started the Iteration 89
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.9356
# 10/10 - 4s - loss: 0.8451
# 10/10 - 3s - loss: 0.9495
# 10/10 - 4s - loss: 0.8126
# 10/10 - 3s - loss: 0.8127
# 10/10 - 3s - loss: 0.8301
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9689
# The minimum train loss in iteration 89: 0.8124789595603943  The test loss is  0.9688575267791748
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5]
# *************   Started the Iteration 90
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8633
# 10/10 - 4s - loss: 0.8185
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 16.4372
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 4.6237
# 10/10 - 4s - loss: 167793.4844
# 2/2 - 0s - loss: 0.9689
# The minimum train loss in iteration 90: 0.8124789595603943  The test loss is  0.9688575267791748
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5]
# *************   Started the Iteration 91
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 3.0974
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8374
# 10/10 - 3s - loss: 2.0881
# 10/10 - 3s - loss: 0.9770
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9688
# The minimum train loss in iteration 91: 0.8124785423278809  The test loss is  0.968766987323761
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3]
# *************   Started the Iteration 92
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8170
# 10/10 - 3s - loss: 0.8146
# 10/10 - 3s - loss: 0.8378
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8945
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9688
# The minimum train loss in iteration 92: 0.812475860118866  The test loss is  0.968754231929779
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5]
# *************   Started the Iteration 93
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8418
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 2.3817
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8320
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 93: 0.8124732971191406  The test loss is  0.9686928987503052
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5]
# *************   Started the Iteration 94
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8215
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 35.3149
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8161
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 94: 0.8124724626541138  The test loss is  0.9686933755874634
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3]
# *************   Started the Iteration 95
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8276
# 10/10 - 4s - loss: 0.8434
# 10/10 - 3s - loss: 0.8300
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.9793
# 10/10 - 4s - loss: 0.8939
# 10/10 - 3s - loss: 0.8422
# 10/10 - 3s - loss: 0.8125
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 95: 0.8124724626541138  The test loss is  0.9686933755874634
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3]
# *************   Started the Iteration 96
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8314
# 10/10 - 3s - loss: 21209.4570
# 10/10 - 4s - loss: 0.8126
# 10/10 - 3s - loss: 0.8390
# 10/10 - 4s - loss: 1.0251
# 10/10 - 3s - loss: 0.8176
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8458
# 10/10 - 3s - loss: 0.8379
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 96: 0.8124699592590332  The test loss is  0.9686879515647888
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3, 7]
# *************   Started the Iteration 97
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8126
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8376
# 10/10 - 4s - loss: 2.3817
# 10/10 - 3s - loss: 0.8395
# 10/10 - 4s - loss: 0.8125
# 10/10 - 4s - loss: 0.9060
# 10/10 - 3s - loss: 0.8305
# 10/10 - 3s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 97: 0.8124690651893616  The test loss is  0.9686959981918335
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3, 7, 3]
# *************   Started the Iteration 98
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8423
# 10/10 - 4s - loss: 0.8333
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8502
# 10/10 - 3s - loss: 0.8492
# 10/10 - 5s - loss: 0.8125
# 2/2 - 0s - loss: 0.9687
# The minimum train loss in iteration 98: 0.8124690651893616  The test loss is  0.9686959981918335
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3, 7, 3]
# *************   Started the Iteration 99
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8360
# 10/10 - 3s - loss: 0.8457
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 2/2 - 0s - loss: 0.9688
# The minimum train loss in iteration 99: 0.8124450445175171  The test loss is  0.968833327293396
# The important mutation fucntions are: [4, 3, 1, 1, 3, 3, 5, 1, 5, 5, 1, 1, 3, 7, 1, 7, 7, 1, 7, 5, 3, 3, 1, 3, 5, 1, 3, 5, 7, 1, 5, 1, 5, 7, 5, 5, 3, 3, 7, 1, 7, 5, 3, 7, 1, 7, 3, 5, 1, 3, 3, 1, 5, 5, 3, 7, 1, 1, 1, 5, 1, 7, 3, 1, 7, 1, 7, 5, 5, 3, 5, 3, 1, 7, 1, 7, 7, 5, 3, 1, 7, 7, 3, 7, 1, 1, 1, 1, 1, 5, 5, 3, 7, 7, 3, 5, 5, 3, 1, 5, 3, 5, 5, 3, 7, 3, 1, 1]

# %% [markdown]
# Seach Based on Weights based Combined Weights and Conceptual Expansion!

# %%
fitness(model)
# Out:
# 10/10 - 2s - loss: 0.8134
# 0.8133947849273682

# %%
import os
iterations = 100
neighbours_count = 10
min_loss = 10e6

base_model = model
base_alphas = []
imp_mut_func = []
for layer in base_model.get_weights():
    alpha_layer = np.ones(layer.shape)
    base_alphas.append(alpha_layer)
for ix in range(iterations):
    # Generate 10 neighbours
    print(f"*************   Started the Iteration {ix}")  
    models = [base_model]
    models_alpha = [base_alphas]
    mutation_fun = []
    for j in range(0, neighbours_count-1):
        ## In each mutation fucntion the alpha values will already be muliplied and the alpha values alone are also sepreately returned
        model_weightss, model_alpha, mut_func = combined_mutation(base_model, base_alphas)
        models.append(model_weightss)
        models_alpha.append(model_alpha)
        mutation_fun.append(mut_func)
    for i, (model_x, alphas) in enumerate(zip(models, models_alpha)):
        if fitness(model_x) < min_loss:
            min_loss = fitness(model_x)
            base_model = model_x
            base_alphas = models_alpha[i]
            imp_mut_func.append(mutation_fun[i-1])
    print(f"The minimum train loss in iteration {ix}:", min_loss, " The test loss is ", test_loss(base_model))
    print("The important mutation fucntions are:", imp_mut_func)
base_model.save("run3_best_model_Combined_in_CE_based_model_for_DNA_new_dimensions_to_health_outcomes_200_iterations.h5")
# Out:
# *************   Started the Iteration 0
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index6 to the source index is 3
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 10 from the source index is 1
#  Swapping values at target index 6 and source index is 4
#  Swapping values at target index 10 and source index is 3
#  Replacing values in target index 1 from the source index is 6
# 10/10 - 2s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8589
# 10/10 - 3s - loss: 0.8239
# 10/10 - 4s - loss: 1.2041
# 10/10 - 3s - loss: 0.8241
# 10/10 - 4s - loss: 0.8583
# 10/10 - 3s - loss: 0.9599
# 10/10 - 3s - loss: 0.9132
# 10/10 - 4s - loss: 0.9361
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 0: 0.8133933544158936  The test loss is  0.9676008820533752
# The important mutation fucntions are: [10, 3]
# *************   Started the Iteration 1
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in Adding target index3 to the source index is 7
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8142
# 10/10 - 4s - loss: 0.8494
# 10/10 - 3s - loss: 0.8333
# 10/10 - 3s - loss: 0.8402
# 10/10 - 3s - loss: 0.8159
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 1.3647
# 10/10 - 3s - loss: 0.8217
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 1: 0.8133933544158936  The test loss is  0.9676008820533752
# The important mutation fucntions are: [10, 3]
# *************   Started the Iteration 2
#  Swapping values at target index 7 and source index is 6
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 1.0042
# 10/10 - 3s - loss: 0.8382
# 10/10 - 3s - loss: 0.8459
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8463
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 1.1814
# 10/10 - 3s - loss: 0.9592
# 10/10 - 3s - loss: 0.8134
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 2: 0.8133933544158936  The test loss is  0.9676008820533752
# The important mutation fucntions are: [10, 3]
# *************   Started the Iteration 3
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index7 to the source index is 9
#  Swapping values at target index 1 and source index is 7
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8963
# 10/10 - 4s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8193
# 10/10 - 3s - loss: 0.8347
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.9406
# 10/10 - 3s - loss: 0.8290
# 10/10 - 4s - loss: 0.8577
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 3: 0.8133847117424011  The test loss is  0.9676035642623901
# The important mutation fucntions are: [10, 3, 1]
# *************   Started the Iteration 4
#  Swapping values at target index 7 and source index is 3
# Mutaion operation X where multiplying alpha with random range for a layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 10 from the source index is 7
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8952
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 0.8303
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8509
# 10/10 - 4s - loss: 0.8380
# 10/10 - 3s - loss: 0.8322
# 10/10 - 3s - loss: 0.8615
# 10/10 - 4s - loss: 0.8136
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 4: 0.8133847117424011  The test loss is  0.9676035642623901
# The important mutation fucntions are: [10, 3, 1]
# *************   Started the Iteration 5
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in target index 1 from the source index is 4
#  Replacing values in Adding target index3 to the source index is 9
#  Replacing values in target index 3 from the source index is 1
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 3 from the source index is 6
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8137
# 10/10 - 4s - loss: 0.8317
# 10/10 - 4s - loss: 0.8340
# 10/10 - 3s - loss: 0.8432
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8135
# 10/10 - 3s - loss: 0.8134
# 10/10 - 3s - loss: 1.3458
# 10/10 - 4s - loss: 0.8134
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 5: 0.8133847117424011  The test loss is  0.9676035642623901
# The important mutation fucntions are: [10, 3, 1]
# *************   Started the Iteration 6
#  Replacing values in Adding target index4 to the source index is 10
#  Swapping values at target index 4 and source index is 7
#  Swapping values at target index 4 and source index is 7
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.9020
# 10/10 - 3s - loss: 0.8330
# 10/10 - 4s - loss: 0.8330
# 10/10 - 3s - loss: 1.0842
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8398
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.9148
# 2/2 - 0s - loss: 0.9676
# The minimum train loss in iteration 6: 0.8133591413497925  The test loss is  0.967583179473877
# The important mutation fucntions are: [10, 3, 1, 1]
# *************   Started the Iteration 7
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in Adding target index1 to the source index is 7
#  Replacing values in Adding target index7 to the source index is 4
#  Replacing values in Adding target index9 to the source index is 6
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8359
# 10/10 - 3s - loss: 0.8134
# 10/10 - 2s - loss: 0.8134
# 10/10 - 4s - loss: 0.8183
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8278
# 10/10 - 3s - loss: 0.8199
# 10/10 - 3s - loss: 0.8139
# 10/10 - 4s - loss: 0.8451
# 10/10 - 3s - loss: 0.8134
# 2/2 - 0s - loss: 0.9671
# The minimum train loss in iteration 7: 0.8132451176643372  The test loss is  0.967056393623352
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11]
# *************   Started the Iteration 8
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in target index 10 from the source index is 3
#  Replacing values in target index 6 from the source index is 3
#  Swapping values at target index 7 and source index is 9
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 9 from the source index is 6
#  Replacing values in target index 3 from the source index is 7
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.9148
# 10/10 - 3s - loss: 0.9096
# 10/10 - 3s - loss: 0.8590
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.9582
# 10/10 - 4s - loss: 0.8168
# 10/10 - 3s - loss: 2.3671
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 2/2 - 0s - loss: 0.9671
# The minimum train loss in iteration 8: 0.8132449984550476  The test loss is  0.967057466506958
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7]
# *************   Started the Iteration 9
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in Adding target index1 to the source index is 7
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in Adding target index7 to the source index is 6
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8383
# 10/10 - 3s - loss: 0.8429
# 10/10 - 4s - loss: 0.8140
# 10/10 - 3s - loss: 1.0289
# 10/10 - 3s - loss: 0.8359
# 10/10 - 4s - loss: 0.8334
# 10/10 - 3s - loss: 1.4344
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 2/2 - 0s - loss: 0.9670
# The minimum train loss in iteration 9: 0.813243567943573  The test loss is  0.9670499563217163
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1]
# *************   Started the Iteration 10
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in target index 10 from the source index is 9
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in target index 7 from the source index is 1
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.8181
# 10/10 - 4s - loss: 0.8563
# 10/10 - 3s - loss: 0.9116
# 10/10 - 3s - loss: 0.8611
# 10/10 - 4s - loss: 0.8538
# 10/10 - 3s - loss: 0.8144
# 10/10 - 3s - loss: 0.8325
# 10/10 - 4s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 2/2 - 0s - loss: 0.9671
# The minimum train loss in iteration 10: 0.8132429718971252  The test loss is  0.9670502543449402
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7]
# *************   Started the Iteration 11
# Applying Weights only Mutation 2! - Adding to an layer
#  Replacing values in target index 10 from the source index is 6
# Applying Weights only Mutation 2! - Adding to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 1 from the source index is 6
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in target index 7 from the source index is 1
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 1.1721
# 10/10 - 4s - loss: 0.9106
# 10/10 - 3s - loss: 1.2180
# 10/10 - 4s - loss: 0.8313
# 10/10 - 3s - loss: 0.9325
# 10/10 - 3s - loss: 0.8252
# 10/10 - 4s - loss: 0.8144
# 10/10 - 3s - loss: 0.9021
# 10/10 - 3s - loss: 4.5600
# 2/2 - 0s - loss: 0.9671
# The minimum train loss in iteration 11: 0.8132429718971252  The test loss is  0.9670502543449402
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7]
# *************   Started the Iteration 12
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 9 from the source index is 1
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index3 to the source index is 4
#  Swapping values at target index 10 and source index is 1
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8342
# 10/10 - 3s - loss: 0.8468
# 10/10 - 4s - loss: 0.8381
# 10/10 - 3s - loss: 1.6243
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8557
# 10/10 - 3s - loss: 0.8726
# 10/10 - 3s - loss: 0.8522
# 10/10 - 4s - loss: 0.8132
# 2/2 - 0s - loss: 0.9671
# The minimum train loss in iteration 12: 0.8132429718971252  The test loss is  0.9670502543449402
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7]
# *************   Started the Iteration 13
# Applying Weights only Mutation 2! - Adding to an layer
#  Replacing values in Adding target index4 to the source index is 1
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8414
# 10/10 - 3s - loss: 0.8949
# 10/10 - 4s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8376
# 10/10 - 4s - loss: 0.8479
# 10/10 - 3s - loss: 0.8405
# 10/10 - 3s - loss: 1.0250
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.8354
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 13: 0.8132156729698181  The test loss is  0.9674226641654968
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1]
# *************   Started the Iteration 14
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index7 to the source index is 10
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in target index 4 from the source index is 3
# Applying Weights only Mutation 6! - Multiplying to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 4.8299
# 10/10 - 3s - loss: 0.9768
# 10/10 - 4s - loss: 0.9908
# 10/10 - 3s - loss: 0.8396
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.9034
# 10/10 - 3s - loss: 0.8574
# 10/10 - 3s - loss: 0.8336
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 14: 0.8132156729698181  The test loss is  0.9674226641654968
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1]
# *************   Started the Iteration 15
#  Replacing values in target index 10 from the source index is 7
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
#  Swapping values at target index 1 and source index is 3
#  Replacing values in Adding target index1 to the source index is 6
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8136
# 10/10 - 4s - loss: 0.8413
# 10/10 - 3s - loss: 0.8431
# 10/10 - 4s - loss: 0.8450
# 10/10 - 3s - loss: 0.8563
# 10/10 - 3s - loss: 0.9835
# 10/10 - 4s - loss: 0.8983
# 10/10 - 3s - loss: 0.8259
# 10/10 - 3s - loss: 0.8135
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 15: 0.8132156729698181  The test loss is  0.9674226641654968
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1]
# *************   Started the Iteration 16
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8138
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 1.1488
# 10/10 - 4s - loss: 0.8332
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8477
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 16: 0.8131644129753113  The test loss is  0.9678796529769897
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3]
# *************   Started the Iteration 17
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Swapping values at target index 4 and source index is 9
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8132
# 10/10 - 4s - loss: 2.3671
# 10/10 - 4s - loss: 640669.8750
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8154
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8581
# 10/10 - 3s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 17: 0.8131644129753113  The test loss is  0.9678796529769897
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3]
# *************   Started the Iteration 18
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
#  Replacing values in Adding target index9 to the source index is 10
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in Adding target index6 to the source index is 3
#  Swapping values at target index 6 and source index is 4
# Mutaion operation X where multiplying alpha with random range for a layer
#  Swapping values at target index 9 and source index is 4
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.9420
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 1.0147
# 10/10 - 4s - loss: 0.8403
# 10/10 - 3s - loss: 0.8135
# 10/10 - 4s - loss: 0.8235
# 10/10 - 3s - loss: 1.1819
# 10/10 - 3s - loss: 0.8339
# 10/10 - 4s - loss: 0.8581
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 18: 0.8131644129753113  The test loss is  0.9678796529769897
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3]
# *************   Started the Iteration 19
#  Replacing values in Adding target index3 to the source index is 1
# Applying Weights only Mutation 2! - Adding to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8699
# 10/10 - 4s - loss: 4.8137
# 10/10 - 3s - loss: 0.8476
# 10/10 - 4s - loss: 0.8899
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8412
# 10/10 - 3s - loss: 0.8132
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8132
# 10/10 - 5s - loss: 1.1783
# 2/2 - 0s - loss: 0.9680
# The minimum train loss in iteration 19: 0.81316077709198  The test loss is  0.9679850339889526
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5]
# *************   Started the Iteration 20
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 5! - Multiplying to an index
#  Replacing values in target index 10 from the source index is 9
#  Replacing values in Adding target index9 to the source index is 1
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8132
# 10/10 - 3s - loss: 0.8350
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8132
# 10/10 - 3s - loss: 0.9674
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8612
# 10/10 - 3s - loss: 0.8485
# 10/10 - 3s - loss: 0.8136
# 2/2 - 0s - loss: 0.9661
# The minimum train loss in iteration 20: 0.8128804564476013  The test loss is  0.9660666584968567
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7]
# *************   Started the Iteration 21
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in target index 6 from the source index is 3
# Applying Weights only Mutation 2! - Adding to an layer
#  Replacing values in target index 7 from the source index is 6
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.9231
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8531
# 10/10 - 3s - loss: 0.9138
# 10/10 - 4s - loss: 0.8410
# 10/10 - 3s - loss: 0.8999
# 10/10 - 4s - loss: 2.3671
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8153
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 21: 0.8128735423088074  The test loss is  0.966367244720459
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7]
# *************   Started the Iteration 22
#  Replacing values in target index 1 from the source index is 3
#  Replacing values in Adding target index7 to the source index is 3
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in target index 9 from the source index is 1
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.9117
# 10/10 - 3s - loss: 0.8339
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8704
# 10/10 - 4s - loss: 5.2972
# 10/10 - 3s - loss: 0.8531
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8459
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 22: 0.8128731846809387  The test loss is  0.9665442109107971
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7]
# *************   Started the Iteration 23
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in Adding target index10 to the source index is 9
#  Replacing values in Adding target index3 to the source index is 1
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 10 from the source index is 4
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8247
# 10/10 - 3s - loss: 0.8265
# 10/10 - 4s - loss: 0.8701
# 10/10 - 3s - loss: 1.3821
# 10/10 - 4s - loss: 0.8328
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8134
# 10/10 - 3s - loss: 0.8292
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 23: 0.8128616809844971  The test loss is  0.96648770570755
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1]
# *************   Started the Iteration 24
#  Swapping values at target index 9 and source index is 7
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index6 to the source index is 7
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
#  Swapping values at target index 3 and source index is 7
#  Replacing values in target index 9 from the source index is 7
# Applying Weights only Mutation 4! - Subtracting to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8595
# 10/10 - 4s - loss: 0.9842
# 10/10 - 3s - loss: 0.8201
# 10/10 - 4s - loss: 0.8181
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.9080
# 10/10 - 4s - loss: 0.8163
# 10/10 - 3s - loss: 0.8270
# 10/10 - 3s - loss: 0.8579
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 24: 0.8128616809844971  The test loss is  0.96648770570755
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1]
# *************   Started the Iteration 25
#  Replacing values in Adding target index6 to the source index is 9
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in Adding target index9 to the source index is 4
#  Replacing values in Adding target index1 to the source index is 7
#  Swapping values at target index 9 and source index is 3
#  Replacing values in Adding target index10 to the source index is 6
# Applying Weights only Mutation 5! - Multiplying to an index
#  Replacing values in target index 1 from the source index is 6
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8332
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8347
# 10/10 - 3s - loss: 0.8138
# 10/10 - 4s - loss: 0.9861
# 10/10 - 3s - loss: 0.8268
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.9378
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 25: 0.8128570914268494  The test loss is  0.9665335416793823
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5]
# *************   Started the Iteration 26
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Mutaion operation X where multiplying alpha with random range for a layer
#  Swapping values at target index 7 and source index is 6
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8251
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.9502
# 10/10 - 4s - loss: 0.8975
# 10/10 - 3s - loss: 0.8240
# 10/10 - 3s - loss: 2.3668
# 10/10 - 4s - loss: 0.9242
# 10/10 - 3s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 26: 0.8128569722175598  The test loss is  0.966533362865448
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3]
# *************   Started the Iteration 27
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 3! - Subtracting to an index
#  Replacing values in target index 9 from the source index is 3
#  Replacing values in Adding target index1 to the source index is 9
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8294
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8139
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.9182
# 10/10 - 3s - loss: 0.8280
# 10/10 - 4s - loss: 0.8129
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8129
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 27: 0.8128533363342285  The test loss is  0.9665355682373047
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7]
# *************   Started the Iteration 28
#  Replacing values in target index 4 from the source index is 7
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 3s - loss: 0.8134
# 10/10 - 4s - loss: 0.8979
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8422
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.8129
# 10/10 - 3s - loss: 0.8829
# 10/10 - 3s - loss: 0.8495
# 2/2 - 0s - loss: 0.9665
# The minimum train loss in iteration 28: 0.8128533363342285  The test loss is  0.9665355682373047
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7]
# *************   Started the Iteration 29
#  Replacing values in target index 6 from the source index is 4
#  Replacing values in Adding target index10 to the source index is 4
# Applying Weights only Mutation 2! - Adding to an layer
#  Swapping values at target index 3 and source index is 1
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# 10/10 - 2s - loss: 0.8129
# 10/10 - 4s - loss: 0.8421
# 10/10 - 4s - loss: 0.8264
# 10/10 - 3s - loss: 1.2035
# 10/10 - 3s - loss: 0.8999
# 10/10 - 4s - loss: 0.8422
# 10/10 - 3s - loss: 0.8236
# 10/10 - 4s - loss: 0.8486
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8262
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 29: 0.8128447532653809  The test loss is  0.9664462208747864
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3]
# *************   Started the Iteration 30
#  Swapping values at target index 4 and source index is 6
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 4 from the source index is 3
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 5s - loss: 1.2001
# 10/10 - 3s - loss: 0.9030
# 10/10 - 4s - loss: 0.8444
# 10/10 - 3s - loss: 0.8471
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 0.9053
# 10/10 - 3s - loss: 0.8129
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 30: 0.8128142356872559  The test loss is  0.9666180610656738
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3]
# *************   Started the Iteration 31
# Mutaion operation X where multiplying alpha with random range for a layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in Adding target index9 to the source index is 3
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in target index 10 from the source index is 7
# Applying Weights only Mutation 3! - Subtracting to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8576
# 10/10 - 4s - loss: 1.0156
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8209
# 10/10 - 4s - loss: 0.8463
# 10/10 - 3s - loss: 0.8131
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 31: 0.8128140568733215  The test loss is  0.9666134715080261
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7]
# *************   Started the Iteration 32
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in Adding target index1 to the source index is 10
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
#  Replacing values in Adding target index3 to the source index is 7
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8140
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.9863
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8322
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8164
# 2/2 - 0s - loss: 0.9666
# The minimum train loss in iteration 32: 0.8128106594085693  The test loss is  0.966591477394104
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5]
# *************   Started the Iteration 33
#  Swapping values at target index 6 and source index is 1
#  Swapping values at target index 7 and source index is 4
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
#  Swapping values at target index 3 and source index is 6
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.9208
# 10/10 - 3s - loss: 0.8330
# 10/10 - 4s - loss: 0.8589
# 10/10 - 3s - loss: 0.8572
# 10/10 - 3s - loss: 0.8129
# 10/10 - 4s - loss: 1.2930
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8354
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 33: 0.8128041625022888  The test loss is  0.9667071104049683
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7]
# *************   Started the Iteration 34
# Applying Weights only Mutation 6! - Multiplying to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
#  Swapping values at target index 10 and source index is 7
#  Swapping values at target index 7 and source index is 9
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8185
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8696
# 10/10 - 3s - loss: 0.8404
# 10/10 - 4s - loss: 0.8595
# 10/10 - 3s - loss: 0.8158
# 10/10 - 3s - loss: 0.8277
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 2/2 - 0s - loss: 0.9667
# The minimum train loss in iteration 34: 0.8128019571304321  The test loss is  0.9667009115219116
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7]
# *************   Started the Iteration 35
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Swapping values at target index 7 and source index is 9
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8267
# 10/10 - 4s - loss: 0.8221
# 10/10 - 3s - loss: 0.8595
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8214
# 10/10 - 3s - loss: 0.8298
# 10/10 - 3s - loss: 0.8397
# 2/2 - 0s - loss: 0.9668
# The minimum train loss in iteration 35: 0.8127837181091309  The test loss is  0.9668043255805969
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1]
# *************   Started the Iteration 36
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
#  Replacing values in target index 10 from the source index is 1
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in Adding target index4 to the source index is 7
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 1.2048
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8584
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8303
# 10/10 - 3s - loss: 0.8132
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 36: 0.8127573132514954  The test loss is  0.9663800597190857
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3]
# *************   Started the Iteration 37
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8357
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8135
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8631
# 10/10 - 3s - loss: 0.8189
# 10/10 - 4s - loss: 0.8428
# 10/10 - 3s - loss: 1.1993
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 37: 0.812755286693573  The test loss is  0.9663739204406738
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5]
# *************   Started the Iteration 38
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 2! - Adding to an layer
#  Replacing values in target index 7 from the source index is 9
#  Replacing values in target index 6 from the source index is 1
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 4s - loss: 0.8141
# 10/10 - 3s - loss: 1.3774
# 10/10 - 3s - loss: 0.8857
# 10/10 - 3s - loss: 2.2296
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8409
# 10/10 - 3s - loss: 0.8592
# 10/10 - 4s - loss: 0.8591
# 10/10 - 3s - loss: 0.8128
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 38: 0.812755286693573  The test loss is  0.9663739204406738
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5]
# *************   Started the Iteration 39
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Swapping values at target index 9 and source index is 10
# Applying Weights only Mutation 1! - Adding to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 7 from the source index is 4
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.9438
# 10/10 - 4s - loss: 0.8431
# 10/10 - 3s - loss: 1.0216
# 10/10 - 4s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8537
# 10/10 - 4s - loss: 0.8297
# 10/10 - 3s - loss: 0.8408
# 10/10 - 3s - loss: 0.8323
# 10/10 - 4s - loss: 0.8132
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 39: 0.81275475025177  The test loss is  0.96637362241745
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1]
# *************   Started the Iteration 40
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 3 from the source index is 9
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in Adding target index9 to the source index is 6
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8617
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8148
# 10/10 - 4s - loss: 0.8538
# 10/10 - 3s - loss: 0.8128
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8187
# 10/10 - 3s - loss: 0.8375
# 2/2 - 0s - loss: 0.9664
# The minimum train loss in iteration 40: 0.8127544522285461  The test loss is  0.9663659334182739
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3]
# *************   Started the Iteration 41
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
#  Swapping values at target index 10 and source index is 6
# 10/10 - 2s - loss: 0.8128
# 10/10 - 3s - loss: 6629.9741
# 10/10 - 4s - loss: 1.2050
# 10/10 - 3s - loss: 0.8901
# 10/10 - 3s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8128
# 10/10 - 4s - loss: 0.8297
# 10/10 - 3s - loss: 0.8525
# 10/10 - 3s - loss: 0.9412
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 41: 0.8127479553222656  The test loss is  0.9674076437950134
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7]
# *************   Started the Iteration 42
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in target index 1 from the source index is 9
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8128
# 10/10 - 3s - loss: 0.8535
# 10/10 - 4s - loss: 0.8913
# 10/10 - 3s - loss: 0.8448
# 10/10 - 3s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8127
# 10/10 - 3s - loss: 0.8592
# 10/10 - 3s - loss: 0.8192
# 10/10 - 4s - loss: 0.8127
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 42: 0.8127439022064209  The test loss is  0.9674155712127686
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1]
# *************   Started the Iteration 43
#  Swapping values at target index 7 and source index is 10
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in Adding target index1 to the source index is 7
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in Adding target index7 to the source index is 6
# Applying Weights only Mutation 7! - Dividing to an index
# 10/10 - 2s - loss: 0.8127
# 10/10 - 4s - loss: 0.8404
# 10/10 - 3s - loss: 0.8127
# 10/10 - 4s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 10/10 - 3s - loss: 0.8959
# 10/10 - 4s - loss: 0.8137
# 10/10 - 3s - loss: 2.3675
# 10/10 - 3s - loss: 0.9310
# 10/10 - 4s - loss: 0.8352
# 10/10 - 3s - loss: 0.8127
# 10/10 - 2s - loss: 0.8127
# 2/2 - 0s - loss: 0.9674
# The minimum train loss in iteration 43: 0.8127431273460388  The test loss is  0.9674168825149536
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7]
# *************   Started the Iteration 44
#  Replacing values in target index 9 from the source index is 3
# Applying Weights only Mutation 3! - Subtracting to an index
# ...
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8125
# 10/10 - 3s - loss: 0.8128
# 10/10 - 3s - loss: 0.8438
# 10/10 - 3s - loss: 1.1016
# 10/10 - 4s - loss: 0.8174
# 10/10 - 3s - loss: 1.2051
# 10/10 - 4s - loss: 0.8425
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8396
# 10/10 - 4s - loss: 0.8294
# 2/2 - 0s - loss: 0.9682
# The minimum train loss in iteration 87: 0.8124684691429138  The test loss is  0.9682126045227051
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7]
# *************   Started the Iteration 88
# Applying Weights only Mutation 3! - Subtracting to an index
#  Replacing values in target index 1 from the source index is 7
#  Replacing values in Adding target index3 to the source index is 9
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
# 10/10 - 2s - loss: 0.8125
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 0.8130
# 10/10 - 3s - loss: 0.8344
# 10/10 - 3s - loss: 0.8605
# 10/10 - 3s - loss: 1.0132
# 10/10 - 4s - loss: 0.8261
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8379
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 88: 0.8124470114707947  The test loss is  0.9679461121559143
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3]
# *************   Started the Iteration 89
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 2! - Adding to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8231
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8423
# 10/10 - 3s - loss: 1.6204
# 10/10 - 3s - loss: 0.8491
# 10/10 - 4s - loss: 0.8134
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 89: 0.8124468922615051  The test loss is  0.9679459929466248
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5]
# *************   Started the Iteration 90
# Applying Weights only Mutation 3! - Subtracting to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8337
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 4s - loss: 0.8258
# 10/10 - 3s - loss: 0.8236
# 10/10 - 3s - loss: 0.8127
# 10/10 - 4s - loss: 0.8223
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 90: 0.8124457001686096  The test loss is  0.9679182171821594
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5]
# *************   Started the Iteration 91
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 9 from the source index is 6
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in target index 3 from the source index is 4
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8400
# 10/10 - 3s - loss: 0.8125
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8130
# 10/10 - 4s - loss: 0.9600
# 10/10 - 3s - loss: 0.9740
# 10/10 - 3s - loss: 0.8838
# 10/10 - 4s - loss: 0.8897
# 10/10 - 3s - loss: 0.8317
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 91: 0.8124457001686096  The test loss is  0.9679182171821594
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5]
# *************   Started the Iteration 92
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in Adding target index3 to the source index is 1
#  Swapping values at target index 1 and source index is 7
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 7! - Dividing to an index
#  Swapping values at target index 9 and source index is 4
#  Replacing values in Adding target index7 to the source index is 6
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8243
# 10/10 - 4s - loss: 0.8708
# 10/10 - 3s - loss: 0.9024
# 10/10 - 3s - loss: 0.8124
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8585
# 10/10 - 4s - loss: 0.8353
# 10/10 - 3s - loss: 0.8125
# 10/10 - 3s - loss: 0.8124
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 92: 0.8124457001686096  The test loss is  0.9679182171821594
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5]
# *************   Started the Iteration 93
# Applying Weights only Mutation 3! - Subtracting to an index
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 8! - Dividing to an layer
# Mutaion operation X where multiplying alpha with random range for a layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Replacing values in target index 4 from the source index is 9
#  Replacing values in target index 10 from the source index is 6
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 1.5090
# 10/10 - 4s - loss: 0.8125
# 10/10 - 3s - loss: 1.1706
# 10/10 - 3s - loss: 0.8340
# 10/10 - 4s - loss: 0.8217
# 10/10 - 3s - loss: 0.8592
# 10/10 - 3s - loss: 0.8999
# 10/10 - 4s - loss: 0.8127
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 93: 0.8124457001686096  The test loss is  0.9679182171821594
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5]
# *************   Started the Iteration 94
#  Swapping values at target index 6 and source index is 9
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 4! - Subtracting to an layer
#  Replacing values in target index 3 from the source index is 1
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 1! - Adding to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.9694
# 10/10 - 3s - loss: 0.8838
# 10/10 - 3s - loss: 0.8191
# 10/10 - 3s - loss: 1.0447
# 10/10 - 4s - loss: 0.8426
# 10/10 - 3s - loss: 0.8399
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8176
# 10/10 - 3s - loss: 0.8401
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 94: 0.8124451041221619  The test loss is  0.9679182171821594
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1]
# *************   Started the Iteration 95
#  Replacing values in target index 9 from the source index is 6
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Replacing values in target index 4 from the source index is 7
# Applying Weights only Mutation 4! - Subtracting to an layer
# Applying Weights only Mutation 5! - Multiplying to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 6! - Multiplying to an layer
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.9594
# 10/10 - 4s - loss: 1.3131
# 10/10 - 3s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8131
# 10/10 - 3s - loss: 0.8365
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8805
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 95: 0.8124444484710693  The test loss is  0.9678962826728821
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1, 7]
# *************   Started the Iteration 96
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 2! - Adding to an layer
#  Replacing values in target index 7 from the source index is 3
# Applying Weights only Mutation 7! - Dividing to an index
#  Replacing values in target index 3 from the source index is 1
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
#  Replacing values in Adding target index1 to the source index is 4
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 1.2051
# 10/10 - 3s - loss: 0.9092
# 10/10 - 4s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8426
# 10/10 - 3s - loss: 0.8304
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8239
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 96: 0.8123658895492554  The test loss is  0.9679007530212402
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1, 7, 3, 7]
# *************   Started the Iteration 97
# Mutaion operation X where multiplying alpha with random range for a layer
#  Replacing values in target index 3 from the source index is 4
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Swapping values at target index 3 and source index is 4
#  Swapping values at target index 10 and source index is 1
#  Swapping values at target index 9 and source index is 4
# Applying Weights only Mutation 1! - Adding to an index
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8154
# 10/10 - 4s - loss: 0.8314
# 10/10 - 3s - loss: 0.8213
# 10/10 - 4s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 1.1552
# 10/10 - 4s - loss: 0.8520
# 10/10 - 3s - loss: 0.8586
# 10/10 - 3s - loss: 0.8124
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 97: 0.812362790107727  The test loss is  0.967901349067688
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1, 7, 3, 7, 3, 1]
# *************   Started the Iteration 98
# Applying Weights only Mutation 7! - Dividing to an index
#  Swapping values at target index 7 and source index is 9
#  Swapping values at target index 9 and source index is 6
#  Replacing values in Adding target index4 to the source index is 3
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 7! - Dividing to an index
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 8! - Dividing to an layer
#  Replacing values in target index 6 from the source index is 9
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 4s - loss: 0.8597
# 10/10 - 3s - loss: 0.9702
# 10/10 - 3s - loss: 0.8214
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8124
# 10/10 - 3s - loss: 144837.3125
# 10/10 - 3s - loss: 0.8623
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 98: 0.8123610019683838  The test loss is  0.9678909778594971
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1, 7, 3, 7, 3, 1, 7]
# *************   Started the Iteration 99
# Applying Weights only Mutation 2! - Adding to an layer
# Applying Weights only Mutation 3! - Subtracting to an index
# Applying Weights only Mutation 1! - Adding to an index
#  Swapping values at target index 10 and source index is 9
# Applying Weights only Mutation 6! - Multiplying to an layer
# Applying Weights only Mutation 6! - Multiplying to an layer
#  Swapping values at target index 1 and source index is 9
# Applying Weights only Mutation 8! - Dividing to an layer
#  Swapping values at target index 7 and source index is 4
# 10/10 - 2s - loss: 0.8124
# 10/10 - 4s - loss: 0.8477
# 10/10 - 3s - loss: 0.8135
# 10/10 - 4s - loss: 0.8124
# 10/10 - 2s - loss: 0.8124
# 10/10 - 3s - loss: 1.1008
# 10/10 - 3s - loss: 0.8376
# 10/10 - 4s - loss: 0.8389
# 10/10 - 3s - loss: 0.8610
# 10/10 - 3s - loss: 0.8527
# 10/10 - 4s - loss: 0.8325
# 2/2 - 0s - loss: 0.9679
# The minimum train loss in iteration 99: 0.812360942363739  The test loss is  0.9678916931152344
# The important mutation fucntions are: [10, 3, 1, 1, 7, 11, 7, 1, 7, 1, 3, 3, 5, 7, 7, 7, 1, 5, 5, 3, 3, 7, 3, 3, 7, 5, 7, 7, 7, 7, 1, 3, 5, 1, 3, 7, 1, 5, 7, 3, 5, 5, 3, 1, 3, 5, 3, 3, 3, 5, 7, 7, 1, 7, 1, 5, 7, 1, 1, 7, 1, 1, 7, 5, 3, 3, 3, 1, 7, 5, 7, 3, 3, 5, 5, 1, 7, 3, 7, 3, 1, 7, 1]

# %% [markdown]
# Search Based on Weights Start Conceptual Expansion!

# %%
import os
iterations = 100
neighbours_count = 10
min_loss = 10e6

base_model = model
base_alphas = []
for layer in base_model.get_weights():
    alpha_layer = np.ones(layer.shape)
    base_alphas.append(alpha_layer)
for i in range(iterations):
    # Generate 10 neighbours
    print(f"*************   Started the Iteration {i}")  
    models = [base_model]
    models_alpha = [base_alphas]
    for j in range(0, neighbours_count-1):
        ## In each mutation fucntion the alpha values will already be muliplied and the alpha values alone are also sepreately returned
        model_weightss, model_alpha = mutation(base_model, base_alphas)
        models.append(model_weightss)
        models_alpha.append(model_alpha)
    for i, (model_x, alphas) in enumerate(zip(models, models_alpha)):
        if fitness(model_x) < min_loss:
            min_loss = fitness(model_x)
            base_model = model_x
            base_alphas = models_alpha[i]
    print(f"The minimum train loss in iteration {i}:", min_loss, " The test loss is ", test_loss(base_model))
base_model.save("run3_best_model_CE_based_model_for_DNA_new_dimensions_to_health_outcomes_200_iterations.h5")
# Out:
# *************   Started the Iteration 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28528/2637666424.py in <module>
#      16     for j in range(0, neighbours_count-1):
#      17         ## In each mutation fucntion the alpha values will already be muliplied and the alpha values alone are also sepreately returned
# ---> 18         model_weightss, model_alpha = mutation(base_model, base_alphas)
#      19         models.append(model_weightss)
#      20         models_alpha.append(model_alpha)
#
# NameError: name 'mutation' is not defined
